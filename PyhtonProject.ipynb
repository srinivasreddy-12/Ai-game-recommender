# %% [markdown]
# <a href="https://colab.research.google.com/github/srinivasreddy-12/Ai-game-recommender/blob/main/PyhtonProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/deepfake_detection_dataset_extended.csv')
df
# Out:
#      File_ID File_Type  Face_Landmark_Distortion  Eye_Blink_Rate  \
# 0    FILE001     Video                      0.68            0.00
# 1    FILE002     Image                      0.57             NaN
# 2    FILE003     Video                      0.66            0.00
# 3    FILE004     Video                      0.64           18.00
# 4    FILE005     Video                      0.46            1.00
# ..       ...       ...                       ...             ...
# 495  FILE496     Video                      0.77            8.81
# 496  FILE497     Image                      0.74             NaN
# 497  FILE498     Video                      0.62           25.03
# 498  FILE499     Video                      0.78             NaN
# 499  FILE500     Image                      0.76             NaN
#
#      Head_Movement_Consistency  Lip_Sync_Error  Texture_Artifacts_Score  \
# 0                         0.69            0.35                     0.50
# 1                          NaN             NaN                     0.74
# 2                         0.67            0.39                     0.62
# 3                         0.47            0.35                     0.66
# 4                         0.37            0.20                     0.74
# ..                         ...             ...                      ...
# 495                       0.52            0.26                     0.72
# 496                        NaN             NaN                     0.81
# 497                       0.41            0.08                     0.60
# 498                        NaN             NaN                     0.72
# 499                        NaN             NaN                     0.68
#
#      Audio_Visual_Mismatch Compression_Level  Is_Deepfake
# 0                     0.22               Low            0
# 1                      NaN              High            1
# 2                     0.59               Low            1
# 3                     0.02              High            0
# 4                     0.57               Low            1
# ..                     ...               ...          ...
# 495                   0.36              High            0
# 496                    NaN              High            0
# 497                   0.11              High            1
# 498                    NaN               Low            1
# 499                    NaN              High            1
#
# [500 rows x 10 columns]

# %%
df.head()
# Out:
#    File_ID File_Type  Face_Landmark_Distortion  Eye_Blink_Rate  \
# 0  FILE001     Video                      0.68             0.0
# 1  FILE002     Image                      0.57             NaN
# 2  FILE003     Video                      0.66             0.0
# 3  FILE004     Video                      0.64            18.0
# 4  FILE005     Video                      0.46             1.0
#
#    Head_Movement_Consistency  Lip_Sync_Error  Texture_Artifacts_Score  \
# 0                       0.69            0.35                     0.50
# 1                        NaN             NaN                     0.74
# 2                       0.67            0.39                     0.62
# 3                       0.47            0.35                     0.66
# 4                       0.37            0.20                     0.74
#
#    Audio_Visual_Mismatch Compression_Level  Is_Deepfake
# 0                   0.22               Low            0
# 1                    NaN              High            1
# 2                   0.59               Low            1
# 3                   0.02              High            0
# 4                   0.57               Low            1

# %%
df.tail()
# Out:
#      File_ID File_Type  Face_Landmark_Distortion  Eye_Blink_Rate  \
# 495  FILE496     Video                      0.77            8.81
# 496  FILE497     Image                      0.74             NaN
# 497  FILE498     Video                      0.62           25.03
# 498  FILE499     Video                      0.78             NaN
# 499  FILE500     Image                      0.76             NaN
#
#      Head_Movement_Consistency  Lip_Sync_Error  Texture_Artifacts_Score  \
# 495                       0.52            0.26                     0.72
# 496                        NaN             NaN                     0.81
# 497                       0.41            0.08                     0.60
# 498                        NaN             NaN                     0.72
# 499                        NaN             NaN                     0.68
#
#      Audio_Visual_Mismatch Compression_Level  Is_Deepfake
# 495                   0.36              High            0
# 496                    NaN              High            0
# 497                   0.11              High            1
# 498                    NaN               Low            1
# 499                    NaN              High            1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   File_ID                    500 non-null    object
#  1   File_Type                  500 non-null    object
#  2   Face_Landmark_Distortion   500 non-null    float64
#  3   Eye_Blink_Rate             278 non-null    float64
#  4   Head_Movement_Consistency  278 non-null    float64
#  5   Lip_Sync_Error             278 non-null    float64
#  6   Texture_Artifacts_Score    500 non-null    float64
#  7   Audio_Visual_Mismatch      278 non-null    float64
#  8   Compression_Level          500 non-null    object
#  9   Is_Deepfake                500 non-null    int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 39.2+ KB

# %%
df.isnull()
# Out:
#      File_ID  File_Type  Face_Landmark_Distortion  Eye_Blink_Rate  \
# 0      False      False                     False           False
# 1      False      False                     False            True
# 2      False      False                     False           False
# 3      False      False                     False           False
# 4      False      False                     False           False
# ..       ...        ...                       ...             ...
# 495    False      False                     False           False
# 496    False      False                     False            True
# 497    False      False                     False           False
# 498    False      False                     False            True
# 499    False      False                     False            True
#
#      Head_Movement_Consistency  Lip_Sync_Error  Texture_Artifacts_Score  \
# 0                        False           False                    False
# 1                         True            True                    False
# 2                        False           False                    False
# 3                        False           False                    False
# 4                        False           False                    False
# ..                         ...             ...                      ...
# 495                      False           False                    False
# 496                       True            True                    False
# 497                      False           False                    False
# 498                       True            True                    False
# 499                       True            True                    False
#
#      Audio_Visual_Mismatch  Compression_Level  Is_Deepfake
# 0                    False              False        False
# 1                     True              False        False
# 2                    False              False        False
# 3                    False              False        False
# 4                    False              False        False
# ..                     ...                ...          ...
# 495                  False              False        False
# 496                   True              False        False
# 497                  False              False        False
# 498                   True              False        False
# 499                   True              False        False
#
# [500 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# File_ID                        0
# File_Type                      0
# Face_Landmark_Distortion       0
# Eye_Blink_Rate               222
# Head_Movement_Consistency    222
# Lip_Sync_Error               222
# Texture_Artifacts_Score        0
# Audio_Visual_Mismatch        222
# Compression_Level              0
# Is_Deepfake                    0
# dtype: int64

# %%
df.describe()
# Out:
#        Face_Landmark_Distortion  Eye_Blink_Rate  Head_Movement_Consistency  \
# count                500.000000      278.000000                 278.000000
# mean                   0.557840       13.410935                   0.565288
# std                    0.155431        8.754368                   0.160922
# min                    0.100000        0.000000                   0.300000
# 25%                    0.460000        5.072500                   0.430000
# 50%                    0.580000       12.960000                   0.555000
# 75%                    0.680000       20.605000                   0.707500
# max                    0.800000       29.840000                   0.980000
#
#        Lip_Sync_Error  Texture_Artifacts_Score  Audio_Visual_Mismatch  \
# count      278.000000               500.000000             278.000000
# mean         0.312662                 0.622460               0.299029
# std          0.169829                 0.182836               0.181062
# min          0.000000                 0.110000               0.000000
# 25%          0.180000                 0.500000               0.142500
# 50%          0.310000                 0.640000               0.280000
# 75%          0.460000                 0.770000               0.450000
# max          0.600000                 0.900000               0.690000
#
#        Is_Deepfake
# count   500.000000
# mean      0.476000
# std       0.499924
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df["Eye_Blink_Rate"].mean()
# Out:
# 13.410935251798561

# %%
df["Eye_Blink_Rate"].median()
# Out:
# 12.96

# %%
correlation=df["Face_Landmark_Distortion"].corr(df["Is_Deepfake"])
print(correlation)
# Out:
# 0.013258309893608562

# %%
covariance=df["Face_Landmark_Distortion"].cov(df["Is_Deepfake"])
print(covariance)
# Out:
# 0.0010302204408817676

# %%
Head_Movement_Average = df.groupby("Head_Movement_Consistency")["Is_Deepfake"].mean()
print(Head_Movement_Average)
Lip_sync_error_Average = df.groupby("Lip_Sync_Error")["Is_Deepfake"].mean()
print(Lip_sync_error_Average)
Eye_Blink_Rate_Average = df.groupby("Eye_Blink_Rate")["Is_Deepfake"].mean()
print(Eye_Blink_Rate_Average)
Face_Landmark_Distortion_Average = df.groupby("Face_Landmark_Distortion")["Is_Deepfake"].mean()
print(Face_Landmark_Distortion_Average)
Texture_Artifacts_Score_Average = df.groupby("Texture_Artifacts_Score")["Is_Deepfake"].mean()
print(Texture_Artifacts_Score_Average)
Audio_Visual_Mismatch_Average = df.groupby("Audio_Visual_Mismatch")["Is_Deepfake"].mean()
print(Audio_Visual_Mismatch_Average)
# Out:
# Head_Movement_Consistency
# 0.30    0.333333
# 0.31    0.250000
# 0.32    0.000000
# 0.33    0.166667
# 0.34    0.750000
# 0.35    1.000000
# 0.36    0.750000
# 0.37    0.600000
# 0.38    0.400000
# 0.39    0.500000
# 0.40    0.142857
# 0.41    0.333333
# 0.42    0.500000
# 0.43    0.428571
# 0.44    0.666667
# 0.45    0.750000
# 0.46    0.800000
# 0.47    0.285714
# 0.48    0.250000
# 0.49    0.500000
# 0.50    0.800000
# 0.51    1.000000
# 0.52    0.285714
# 0.53    0.333333
# 0.54    0.200000
# 0.55    0.333333
# 0.56    0.500000
# 0.57    0.500000
# 0.58    0.600000
# 0.59    0.500000
# 0.60    0.375000
# 0.61    0.500000
# 0.62    0.250000
# 0.63    0.333333
# 0.64    0.666667
# 0.65    0.500000
# 0.66    1.000000
# 0.67    0.500000
# 0.68    0.600000
# 0.69    0.285714
# 0.70    0.250000
# 0.71    0.600000
# 0.72    0.625000
# 0.73    0.714286
# 0.74    0.500000
# 0.75    0.375000
# 0.76    0.285714
# 0.77    0.500000
# 0.78    0.400000
# 0.79    0.500000
# 0.80    0.000000
# 0.81    1.000000
# 0.82    1.000000
# 0.85    0.000000
# 0.86    0.000000
# 0.89    0.000000
# 0.92    0.500000
# 0.93    0.500000
# 0.98    1.000000
# Name: Is_Deepfake, dtype: float64
# Lip_Sync_Error
# 0.00    0.333333
# 0.01    0.500000
# 0.02    1.000000
# 0.03    0.000000
# 0.04    0.666667
#           ...
# 0.56    0.285714
# 0.57    0.500000
# 0.58    0.750000
# 0.59    0.500000
# 0.60    0.333333
# Name: Is_Deepfake, Length: 61, dtype: float64
# Eye_Blink_Rate
# 0.00     0.8
# 0.19     0.0
# 0.25     1.0
# 0.28     0.0
# 0.43     1.0
#         ...
# 29.31    0.0
# 29.32    0.5
# 29.37    0.0
# 29.66    0.0
# 29.84    0.0
# Name: Is_Deepfake, Length: 241, dtype: float64
# Face_Landmark_Distortion
# 0.10    1.000000
# 0.12    0.666667
# 0.13    0.000000
# 0.14    0.000000
# 0.15    0.500000
#           ...
# 0.76    0.555556
# 0.77    0.692308
# 0.78    0.538462
# 0.79    0.200000
# 0.80    0.333333
# Name: Is_Deepfake, Length: 66, dtype: float64
# Texture_Artifacts_Score
# 0.11    0.500000
# 0.12    0.666667
# 0.13    0.000000
# 0.14    0.000000
# 0.16    0.500000
#           ...
# 0.86    0.642857
# 0.87    0.500000
# 0.88    0.300000
# 0.89    0.777778
# 0.90    0.375000
# Name: Is_Deepfake, Length: 71, dtype: float64
# Audio_Visual_Mismatch
# 0.00    0.000000
# 0.01    0.857143
# 0.02    0.000000
# 0.03    0.142857
# 0.04    0.400000
#           ...
# 0.61    0.000000
# 0.63    0.333333
# 0.65    0.000000
# 0.67    1.000000
# 0.69    1.000000
# Name: Is_Deepfake, Length: 65, dtype: float64

# %%
df = df.fillna(method = "bfill")
df = df.fillna(method = "ffill")
df
# Out:
# <ipython-input-19-93bf9f6ce18f>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method = "bfill")
# <ipython-input-19-93bf9f6ce18f>:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method = "ffill")
#      File_ID File_Type  Face_Landmark_Distortion  Eye_Blink_Rate  \
# 0    FILE001     Video                      0.68            0.00
# 1    FILE002     Image                      0.57            0.00
# 2    FILE003     Video                      0.66            0.00
# 3    FILE004     Video                      0.64           18.00
# 4    FILE005     Video                      0.46            1.00
# ..       ...       ...                       ...             ...
# 495  FILE496     Video                      0.77            8.81
# 496  FILE497     Image                      0.74           25.03
# 497  FILE498     Video                      0.62           25.03
# 498  FILE499     Video                      0.78           25.03
# 499  FILE500     Image                      0.76           25.03
#
#      Head_Movement_Consistency  Lip_Sync_Error  Texture_Artifacts_Score  \
# 0                         0.69            0.35                     0.50
# 1                         0.67            0.39                     0.74
# 2                         0.67            0.39                     0.62
# 3                         0.47            0.35                     0.66
# 4                         0.37            0.20                     0.74
# ..                         ...             ...                      ...
# 495                       0.52            0.26                     0.72
# 496                       0.41            0.08                     0.81
# 497                       0.41            0.08                     0.60
# 498                       0.41            0.08                     0.72
# 499                       0.41            0.08                     0.68
#
#      Audio_Visual_Mismatch Compression_Level  Is_Deepfake
# 0                     0.22               Low            0
# 1                     0.59              High            1
# 2                     0.59               Low            1
# 3                     0.02              High            0
# 4                     0.57               Low            1
# ..                     ...               ...          ...
# 495                   0.36              High            0
# 496                   0.11              High            0
# 497                   0.11              High            1
# 498                   0.11               Low            1
# 499                   0.11              High            1
#
# [500 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# File_ID                      0
# File_Type                    0
# Face_Landmark_Distortion     0
# Eye_Blink_Rate               0
# Head_Movement_Consistency    0
# Lip_Sync_Error               0
# Texture_Artifacts_Score      0
# Audio_Visual_Mismatch        0
# Compression_Level            0
# Is_Deepfake                  0
# dtype: int64

# %%
df.nunique()
# Out:
# File_ID                      500
# File_Type                      2
# Face_Landmark_Distortion      66
# Eye_Blink_Rate               241
# Head_Movement_Consistency     59
# Lip_Sync_Error                61
# Texture_Artifacts_Score       71
# Audio_Visual_Mismatch         65
# Compression_Level              3
# Is_Deepfake                    2
# dtype: int64

# %%
print("Head of the DataFrame:")
print(df.head())
print("\nTail of the DataFrame:")
print(df.tail())
print("\nDataFrame Information:")
print(df.info())
print("\nDescriptive Statistics:")
print(df.describe())
print("\nMean of Eye_Blink_Rate:", df["Eye_Blink_Rate"].mean())
print("Median of Eye_Blink_Rate:", df["Eye_Blink_Rate"].median())

correlation = df["Face_Landmark_Distortion"].corr(df["Is_Deepfake"])
print("\nCorrelation between Face_Landmark_Distortion and Is_Deepfake:", correlation)
covariance = df["Face_Landmark_Distortion"].cov(df["Is_Deepfake"])
print("Covariance between Face_Landmark_Distortion and Is_Deepfake:", covariance)

for col in ['Head_Movement_Consistency', 'Lip_Sync_Error', 'Eye_Blink_Rate',
            'Face_Landmark_Distortion', 'Texture_Artifacts_Score', 'Audio_Visual_Mismatch']:
    grouped_avg = df.groupby(col)["Is_Deepfake"].mean()
    print(f"\nAverage Is_Deepfake value grouped by {col}:\n{grouped_avg}")

df = df.fillna(method="bfill")
df = df.fillna(method="ffill")
print("\nNumber of missing values after filling:")
print(df.isnull().sum())
print("\nNumber of unique values in each column:")
print(df.nunique())
# Out:
# Head of the DataFrame:
#    File_ID File_Type  Face_Landmark_Distortion  Eye_Blink_Rate  \
# 0  FILE001     Video                      0.68             0.0
# 1  FILE002     Image                      0.57             0.0
# 2  FILE003     Video                      0.66             0.0
# 3  FILE004     Video                      0.64            18.0
# 4  FILE005     Video                      0.46             1.0
#
#    Head_Movement_Consistency  Lip_Sync_Error  Texture_Artifacts_Score  \
# 0                       0.69            0.35                     0.50
# 1                       0.67            0.39                     0.74
# 2                       0.67            0.39                     0.62
# 3                       0.47            0.35                     0.66
# 4                       0.37            0.20                     0.74
#
#    Audio_Visual_Mismatch Compression_Level  Is_Deepfake
# 0                   0.22               Low            0
# 1                   0.59              High            1
# 2                   0.59               Low            1
# 3                   0.02              High            0
# 4                   0.57               Low            1
#
# Tail of the DataFrame:
#      File_ID File_Type  Face_Landmark_Distortion  Eye_Blink_Rate  \
# 495  FILE496     Video                      0.77            8.81
# 496  FILE497     Image                      0.74           25.03
# 497  FILE498     Video                      0.62           25.03
# 498  FILE499     Video                      0.78           25.03
# 499  FILE500     Image                      0.76           25.03
#
#      Head_Movement_Consistency  Lip_Sync_Error  Texture_Artifacts_Score  \
# 495                       0.52            0.26                     0.72
# 496                       0.41            0.08                     0.81
# 497                       0.41            0.08                     0.60
# 498                       0.41            0.08                     0.72
# 499                       0.41            0.08                     0.68
#
#      Audio_Visual_Mismatch Compression_Level  Is_Deepfake
# 495                   0.36              High            0
# 496                   0.11              High            0
# 497                   0.11              High            1
# 498                   0.11               Low            1
# 499                   0.11              High            1
#
# DataFrame Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   File_ID                    500 non-null    object
#  1   File_Type                  500 non-null    object
#  2   Face_Landmark_Distortion   500 non-null    float64
#  3   Eye_Blink_Rate             500 non-null    float64
#  4   Head_Movement_Consistency  500 non-null    float64
#  5   Lip_Sync_Error             500 non-null    float64
#  6   Texture_Artifacts_Score    500 non-null    float64
#  7   Audio_Visual_Mismatch      500 non-null    float64
#  8   Compression_Level          500 non-null    object
#  9   Is_Deepfake                500 non-null    int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 39.2+ KB
# None
#
# Descriptive Statistics:
#        Face_Landmark_Distortion  Eye_Blink_Rate  Head_Movement_Consistency  \
# count                500.000000      500.000000                 500.000000
# mean                   0.557840       13.147800                   0.565100
# std                    0.155431        8.746669                   0.164434
# min                    0.100000        0.000000                   0.300000
# 25%                    0.460000        5.000000                   0.420000
# 50%                    0.580000       12.570000                   0.540000
# 75%                    0.680000       19.927500                   0.710000
# max                    0.800000       29.840000                   0.980000
#
#        Lip_Sync_Error  Texture_Artifacts_Score  Audio_Visual_Mismatch  \
# count      500.000000               500.000000             500.000000
# mean         0.320160                 0.622460               0.297300
# std          0.165262                 0.182836               0.182654
# min          0.000000                 0.110000               0.000000
# 25%          0.190000                 0.500000               0.140000
# 50%          0.320000                 0.640000               0.290000
# 75%          0.460000                 0.770000               0.460000
# max          0.600000                 0.900000               0.690000
#
#        Is_Deepfake
# count   500.000000
# mean      0.476000
# std       0.499924
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000
#
# Mean of Eye_Blink_Rate: 13.1478
# Median of Eye_Blink_Rate: 12.57
#
# Correlation between Face_Landmark_Distortion and Is_Deepfake: 0.013258309893608562
# Covariance between Face_Landmark_Distortion and Is_Deepfake: 0.0010302204408817676
#
# Average Is_Deepfake value grouped by Head_Movement_Consistency:
# Head_Movement_Consistency
# 0.30    0.166667
# 0.31    0.272727
# 0.32    0.200000
# 0.33    0.125000
# 0.34    0.600000
# 0.35    1.000000
# 0.36    0.533333
# 0.37    0.631579
# 0.38    0.500000
# 0.39    0.615385
# 0.40    0.100000
# 0.41    0.428571
# 0.42    0.500000
# 0.43    0.647059
# 0.44    0.600000
# 0.45    0.571429
# 0.46    0.636364
# 0.47    0.461538
# 0.48    0.357143
# 0.49    0.461538
# 0.50    0.666667
# 0.51    0.750000
# 0.52    0.250000
# 0.53    0.444444
# 0.54    0.375000
# 0.55    0.500000
# 0.56    0.666667
# 0.57    0.500000
# 0.58    0.666667
# 0.59    0.454545
# 0.60    0.333333
# 0.61    0.363636
# 0.62    0.428571
# 0.63    0.333333
# 0.64    0.466667
# 0.65    0.500000
# 0.66    1.000000
# 0.67    0.625000
# 0.68    0.583333
# 0.69    0.333333
# 0.70    0.400000
# 0.71    0.571429
# 0.72    0.600000
# 0.73    0.571429
# 0.74    0.545455
# 0.75    0.333333
# 0.76    0.333333
# 0.77    0.333333
# 0.78    0.500000
# 0.79    0.500000
# 0.80    0.000000
# 0.81    1.000000
# 0.82    1.000000
# 0.85    0.000000
# 0.86    0.583333
# 0.89    0.000000
# 0.92    0.333333
# 0.93    0.500000
# 0.98    1.000000
# Name: Is_Deepfake, dtype: float64
#
# Average Is_Deepfake value grouped by Lip_Sync_Error:
# Lip_Sync_Error
# 0.00    0.333333
# 0.01    0.500000
# 0.02    0.750000
# 0.03    0.000000
# 0.04    0.666667
#           ...
# 0.56    0.352941
# 0.57    0.600000
# 0.58    0.500000
# 0.59    0.571429
# 0.60    0.200000
# Name: Is_Deepfake, Length: 61, dtype: float64
#
# Average Is_Deepfake value grouped by Eye_Blink_Rate:
# Eye_Blink_Rate
# 0.00     0.750000
# 0.19     0.571429
# 0.25     1.000000
# 0.28     0.000000
# 0.43     0.333333
#            ...
# 29.31    0.000000
# 29.32    0.250000
# 29.37    0.000000
# 29.66    0.000000
# 29.84    0.000000
# Name: Is_Deepfake, Length: 241, dtype: float64
#
# Average Is_Deepfake value grouped by Face_Landmark_Distortion:
# Face_Landmark_Distortion
# 0.10    1.000000
# 0.12    0.666667
# 0.13    0.000000
# 0.14    0.000000
# 0.15    0.500000
#           ...
# 0.76    0.555556
# 0.77    0.692308
# 0.78    0.538462
# 0.79    0.200000
# 0.80    0.333333
# Name: Is_Deepfake, Length: 66, dtype: float64
#
# Average Is_Deepfake value grouped by Texture_Artifacts_Score:
# Texture_Artifacts_Score
# 0.11    0.500000
# 0.12    0.666667
# 0.13    0.000000
# 0.14    0.000000
# 0.16    0.500000
#           ...
# 0.86    0.642857
# 0.87    0.500000
# 0.88    0.300000
# 0.89    0.777778
# 0.90    0.375000
# Name: Is_Deepfake, Length: 71, dtype: float64
#
# Average Is_Deepfake value grouped by Audio_Visual_Mismatch:
# Audio_Visual_Mismatch
# 0.00    0.571429
# 0.01    0.777778
# 0.02    0.125000
# 0.03    0.181818
# 0.04    0.454545
#           ...
# 0.61    0.000000
# 0.63    0.200000
# 0.65    0.000000
# 0.67    0.666667
# 0.69    1.000000
# Name: Is_Deepfake, Length: 65, dtype: float64
#
# Number of missing values after filling:
# File_ID                      0
# File_Type                    0
# Face_Landmark_Distortion     0
# Eye_Blink_Rate               0
# Head_Movement_Consistency    0
# Lip_Sync_Error               0
# Texture_Artifacts_Score      0
# Audio_Visual_Mismatch        0
# Compression_Level            0
# Is_Deepfake                  0
# dtype: int64
#
# Number of unique values in each column:
# File_ID                      500
# File_Type                      2
# Face_Landmark_Distortion      66
# Eye_Blink_Rate               241
# Head_Movement_Consistency     59
# Lip_Sync_Error                61
# Texture_Artifacts_Score       71
# Audio_Visual_Mismatch         65
# Compression_Level              3
# Is_Deepfake                    2
# dtype: int64
# <ipython-input-77-efcd14797be5>:22: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method="bfill")
# <ipython-input-77-efcd14797be5>:23: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method="ffill")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(df ["Lip_Sync_Error"], legend="auto", color="skyblue", saturation=0.5,whis=1.5)
plt.title("Boxplot of Lip_Sync_Error", color="green")

plt.grid(alpha=0.3)

plt.show()

# %%
sns.pairplot(df,hue="Lip_Sync_Error", palette="Accent")
plt.show()

# %%
sns.barplot(x=df['Is_Deepfake'], y=df['Texture_Artifacts_Score'], data=df)
plt.title("Texture_Artifacts vs Deepfake")

plt.show()

# %%
df.hist(figsize=(10,12), bins=5)

plt.show()

# %%
import numpy as np
numerical_df = df.select_dtypes(include=np.number)

plt.figure(figsize=(10, 6))

sns.heatmap(numerical_df.corr(), annot=True, cmap='coolwarm')

plt.title("Correlation Heatmap")

plt.show()

# %%
numerical_df = df.select_dtypes (include=np.number)

plt.figure(figsize=(10, 6))

sns.heatmap(numerical_df.cov(), annot=True, cmap='coolwarm')

plt.title("Covariance Heatmap")

plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
sns.barplot(x='Head_Movement_Consistency', y='Is_Deepfake', data=df)
plt.title('Is_Deepfake vs Head_Movement_Consistency')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

palette = sns.color_palette("husl", len(df.dtypes))

plt.figure(figsize=(10, 6))
df.dtypes.value_counts().plot(kind='bar', color=palette)
plt.title('Data Types in Dataset')
plt.xlabel('Data Type')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
df['Is_Deepfake'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Deepfake Videos')
plt.ylabel('')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
X = df[['Face_Landmark_Distortion']]
y = df['Is_Deepfake']
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Face_Landmark_Distortion', y='Is_Deepfake', data=df, color='blue', label='Data Points')
plt.plot(X, y_pred, color='red', linewidth=2, label='Regression Line')
plt.xlabel('Face Landmark Distortion')
plt.ylabel('Is Deepfake')
plt.title('Linear Regression: Face Landmark Distortion vs. Is Deepfake')
plt.legend()
plt.show()

# %%
print(f"Slope: {model.coef_[0]}")
print(f"Intercept: {model.intercept_}")
# Out:
# Slope: 0.04264360063292535
# Intercept: 0.4522116938229289

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


scaler = StandardScaler()
scaled_data = scaler.fit_transform(numerical_df)


pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_data)

pca_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])

plt.figure(figsize=(8, 6))
plt.scatter(pca_df['PC1'], pca_df['PC2'], c=df['Is_Deepfake'], cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Visualization')
plt.colorbar(label='Is_Deepfake')
plt.show()

print("Explained Variance Ratio:", pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio: [0.22601447 0.15856036]

# %%
y_true = df['Is_Deepfake']
y_pred = model.predict(X)

threshold = 0.5
y_pred_class = [1 if p >= threshold else 0 for p in y_pred]
cm = confusion_matrix(y_true, y_pred_class)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
#univariate
plt.figure(figsize=(8, 6))
sns.distplot(df['Lip_Sync_Error'], kde=True)
plt.title('Distribution of Lip Sync Error')
plt.xlabel('Lip Sync Error')
plt.ylabel('Frequency')
plt.show()

plt.figure(figsize=(8, 6))
plt.hist(df['Texture_Artifacts_Score'], bins=10)
plt.title('Histogram of Texture Artifacts Score')
plt.xlabel('Texture Artifacts Score')
plt.ylabel('Frequency')
plt.show()
plt.figure(figsize=(8, 6))
sns.violinplot(y=df['Eye_Blink_Rate'])
plt.title('Violin Plot of Eye Blink Rate')
plt.ylabel('Eye Blink Rate')
plt.show()
# Out:
# <ipython-input-97-02382a849087>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Lip_Sync_Error'], kde=True)

# %%
#bivariate
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Face_Landmark_Distortion', y='Is_Deepfake', hue='Lip_Sync_Error', size='Texture_Artifacts_Score', data=df)
plt.title('Relationship between Features')
plt.xlabel('Face Landmark Distortion')
plt.ylabel('Is Deepfake')
plt.show()
